# %% [markdown]
# # Datatypes
# ![](../images/Datatypes.jpg)
#
#
# ## To Check the Datatype of the data

# %%
isinstance(7,int)
# Out:
# True

# %%
isinstance(8.5,float)
# Out:
# True

# %%
isinstance(7,str)
# Out:
# False

# %%
isinstance("Manikarnika",str)
# Out:
# True

# %% [markdown]
# ```{toctree}
# :hidden:
# :titlesonly:
#
#
# numbers
# dboolean
# dstrings
# dlists
# dset
# dtuple
# dictionary
# ```
