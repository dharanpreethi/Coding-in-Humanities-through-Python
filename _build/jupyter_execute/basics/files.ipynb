# %% [markdown]
# # File
#
# * A file is some information or data which stays in the computer storage devices.
# * Python gives you easy ways to manipulate these files.
# * Generally we divide files in two categories, text file and binary file.
# * Text files are simple text where as the binary files contain binary data which is only readable by computer.
#
# ## Opening the file

# %%
ifile=open("test.txt")

# %% [markdown]
# ## Reading the file

# %%
print(ifile.read())
# Out:
# Introduction
# ============================
#
# As primary sources of information are more frequently digitized and available online than ever before, how can we use those sources to ask new questions? How did Chinese families organize themselves and their landscapes in China's past? How did African slaves from different cultures form communities in the Americas? What influences informed the creation and evolution of Broadway musicals? How can I understand or interpret 1,000 books all at once? How can I create a visualization that my students can interact with? The answers to these questions can be explored using a wide variety of digital tools, methods, and sources....Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data...

# %% [markdown]
# ## Closing the file

# %%
ifile.close()

# %% [markdown]
# ## Appending the file

# %%
ifile=open("test.txt",'a') # a means append
c=ifile.tell() # tells the position of pointer in file
print(c)
a="...Extra data..."
ifile.write(a)
ifile.close()
# Out:
# 958

# %%
ifile=open("test.txt")
print(ifile.read())
ifile.close()
# Out:
# Introduction
# ============================
#
# As primary sources of information are more frequently digitized and available online than ever before, how can we use those sources to ask new questions? How did Chinese families organize themselves and their landscapes in China's past? How did African slaves from different cultures form communities in the Americas? What influences informed the creation and evolution of Broadway musicals? How can I understand or interpret 1,000 books all at once? How can I create a visualization that my students can interact with? The answers to these questions can be explored using a wide variety of digital tools, methods, and sources....Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data...

# %% [markdown]
# ## readline
#
# ### Example

# %%
f=open('test.txt')
s=f.readline() #read line by line
print(s)
# Out:
# Introduction

# %% [markdown]
# ## Seek
#
# seek a particular text in the file
#
# ### syntax
#
# f.seek(offset, from)
#
# Here, the from parameter takes the following values:
#
#     0 : offset calculated from the beginning
#
#     1 : offset calculated from the current position
#
#     2 : offset calculated from the end
#
# Assuming that myfile.txt contains "Hello World" text, the following example demonstrates the seek() method.
#
#
#
# ### Example

# %%
f=open("test.txt","r+")
f.seek(46,0) #seek from 46 th letter
lines=f.readlines()
for line in lines:
    print(line)
f.close()
# Out:
# primary sources of information are more frequently digitized and available online than ever before, how can we use those sources to ask new questions? How did Chinese families organize themselves and their landscapes in China's past? How did African slaves from different cultures form communities in the Americas? What influences informed the creation and evolution of Broadway musicals? How can I understand or interpret 1,000 books all at once? How can I create a visualization that my students can interact with? The answers to these questions can be explored using a wide variety of digital tools, methods, and sources....Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data......Extra data...

# %% [markdown]
# ## To know the file closed or not

# %%
f = open ('test.txt')
f.closed
# Out:
# False

# %% [markdown]
# ## To know file readable or not
# We expect the file to be readable. It was opened without error.

# %%
f.readable()
# Out:
# True

# %% [markdown]
# ## To know file Seekable or not
# We can cause the file to seek to any desired position within the file

# %%
f.seekable()
# Out:
# True

# %% [markdown]
# ## tell()
# Internal pointer is at beginning of file. This is expected after opening file.

# %%
f.tell()
# Out:
# 0

# %% [markdown]
# ## To know file writable or not
# Not writable, opened for reading only. An attempt to write or truncate raises OSError.

# %%
f.writable()
# Out:
# False
